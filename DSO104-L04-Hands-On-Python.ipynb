# %% [markdown]
# ## DSO104 - Data Wrangling and Visualization
# ### Lesson 4 - Displaying Quantitative Data
# ______________
# #### Page 19 - Hands-On
#
# **Import packages**

# %%
import pandas as pd

import seaborn as sns

import matplotlib.mlab as mlab

import matplotlib.pyplot as plt

# %% [markdown]
# #### Part 1
#
# Here's [a listing of the number of power boats](https://repo.exeterlms.com/documents/V2/DataScience/Data-Wrang-Visual/L5P1.zip) registered in Florida (in the 1000's) for each year, 35 years worth of data. Tinker with the settings until you have created a histogram with 7 bars.
#
# **Tip!**
#
# Remember, you can specify the number of bins in Python if you use matplotlib!
#
# **Import data**

# %%
flBoats = pd.read_csv('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 4: Displaying Quantitative Data/Hands-On/L4P1.csv')

# %%
flBoats
# Out:
#     Power Boats (in 1000's)
# 0                       436
# 1                       449
# 2                       470
# 3                       487
# 4                       502
# 5                       501
# 6                       515
# 7                       548
# 8                       575
# 9                       604
# 10                      635
# 11                      665
# 12                      701
# 13                      709
# 14                      671
# 15                      669
# 16                      668
# 17                      686
# 18                      703
# 19                      722
# 20                      745
# 21                      799
# 22                      820
# 23                      869
# 24                      932
# 25                      952
# 26                      969
# 27                      974
# 28                     1001
# 29                     1015
# 30                     1018
# 31                     1001
# ...

# %% [markdown]
# **Create a histogram with matplotlib to be able to define # of bins**

# %%
num_bins = 7
n, bins, patches = plt.hist(flBoats['Power Boats (in 1000\'s)'], 
num_bins, facecolor = 'blue', alpha = 1)
plt.xlabel('1,000\'s of Boats')
plt.ylabel('Frequency')
plt.title('Frequency of 1,000\'s of Registered Power Boats')
plt.show()

# %% [markdown]
# *Note: This is actually 7 bins, though the 3rd and 4th are the same height*
#
# #### Part 2
#
# Use the [following data](https://repo.exeterlms.com/documents/V2/DataScience/Data-Wrang-Visual/L5P2.zip) to create a bar graph
#
# **Import data**

# %%
cars = pd.read_csv('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 4: Displaying Quantitative Data/Hands-On/L4P2.csv')

# %%
cars
# Out:
#           Cars
# 0   Mitsubishi
# 1   Mitsubishi
# 2        Dodge
# 3   Mitsubishi
# 4        Dodge
# ..         ...
# 81      Jaguar
# 82      Jaguar
# 83      Jaguar
# 84  Mitsubishi
# 85      Jaguar
#
# [86 rows x 1 columns]

# %% [markdown]
# **Create bar chart with pandas**

# %%
carBar = cars['Cars'].value_counts().plot(kind = 'bar')
carBar.set_title('Frequency of Car Brands')
carBar.set_xlabel('Car Brands')
carBar.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# *Note: Jaguar is the most popular car in this batch - was a survey of the rich and famous? ;)*
#
# #### Part 3
#
# Use the [following data](https://repo.exeterlms.com/documents/V2/DataScience/Data-Wrang-Visual/L5Part3.zip) to create a stacked bar chart
#
# **Import data**

# %%
carLocations = pd.read_csv('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 4: Displaying Quantitative Data/Hands-On/L4P3.csv')

# %%
carLocations
# Out:
#            Car   Location
# 0         Ford  Northwest
# 1         Ford       East
# 2   Mitsubishi  Northwest
# 3       Datsun  Northwest
# 4   Mitsubishi  Southwest
# ..         ...        ...
# 82      Jaguar  Northwest
# 83      Jaguar  Southwest
# 84        Ford  Southwest
# 85  Mitsubishi       East
# 86       Dodge  Southwest
#
# [87 rows x 2 columns]

# %% [markdown]
# **Create stacked bar chart with pandas**

# %%
carLocationBars = pd.crosstab(carLocations['Car'], carLocations['Location'])
carLocationBars.plot.bar(stacked = True)
# Out:
# <AxesSubplot: xlabel='Car'>

# %% [markdown]
# *Note: Data has more cars from the southwest, which is a little curious...*
#
# #### Part 4
#
# The [following dataset](https://repo.exeterlms.com/documents/V2/DataScience/Data-Wrang-Visual/crocodiles.zip) contains data for estuarine crocodiles, recording their head length and body length. Visualize the data with a clearly labeled scatter plot
#
# **Import data**

# %%
crocodiles = pd.read_csv('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 4: Displaying Quantitative Data/Hands-On/L4P4.csv')

# %%
crocodiles
# Out:
#              CommonName  HeadLength  BodyLength
# 0   Estuarine Crocodile          24         161
# 1   Estuarine Crocodile          24         179
# 2   Estuarine Crocodile          32         226
# 3   Estuarine Crocodile          35         259
# 4   Estuarine Crocodile          40         287
# 5   Estuarine Crocodile          40         300
# 6   Estuarine Crocodile          46         342
# 7   Estuarine Crocodile          48         333
# 8   Estuarine Crocodile          52         406
# 9   Estuarine Crocodile          61         459
# 10  Estuarine Crocodile          51         376
# 11  Estuarine Crocodile          54         380
# 12  Estuarine Crocodile          38         265
# 13  Estuarine Crocodile          46         349
# 14  Estuarine Crocodile          38         264
# 15  Estuarine Crocodile          49         358
# 16  Estuarine Crocodile          39         276
# 17  Estuarine Crocodile          49         356
# 18  Estuarine Crocodile          40         270
# ...

# %% [markdown]
# **Scatter plot with pandas**

# %%
crocodileScatter = crocodiles.plot.scatter(x = 'BodyLength', y = 'HeadLength')
crocodileScatter.set_xlabel('Body Length')
crocodileScatter.set_ylabel('Head Length')
crocodileScatter.set_title('Body Length by Head Length')
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Text(0.5, 1.0, 'Body Length by Head Length')

# %% [markdown]
# *Note: Data appear to be strongly and positively correlated - the longer the crocodile's body, the longer its head*
#
# #### Part 5
#
# Here's [data tracking heart attacks](https://repo.exeterlms.com/documents/V2/DataScience/Data-Wrang-Visual/L5P5.zip) treated at a hospital chain in a large US city. Use this data to create a line chart. Be sure to label the graph, and label both axes
#
# **Import data**

# %%
heartAttacks = pd.read_csv('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 4: Displaying Quantitative Data/Hands-On/L4P5.csv')

# %%
heartAttacks
# Out:
#    Month  Day  Year  Heart Attacks
# 0    May   1,  2003             12
# 1    May   2,  2003             12
# 2    May   3,  2003              6
# 3    May   4,  2003             16
# 4    May   5,  2003             13
# ..   ...  ...   ...            ...
# 86  July  26,  2003             17
# 87  July  27,  2003             19
# 88  July  28,  2003             27
# 89  July  29,  2003             11
# 90  July  30,  2003             18
#
# [91 rows x 4 columns]

# %% [markdown]
# **Wrangle data**

# %%
heartAttacks['Date'] = (heartAttacks['Month'] + ' ' + heartAttacks['Day'])
heartAttacks
# Out:
#    Month  Day  Year  Heart Attacks      Date
# 0    May   1,  2003             12    May 1,
# 1    May   2,  2003             12    May 2,
# 2    May   3,  2003              6    May 3,
# 3    May   4,  2003             16    May 4,
# 4    May   5,  2003             13    May 5,
# ..   ...  ...   ...            ...       ...
# 86  July  26,  2003             17  July 26,
# 87  July  27,  2003             19  July 27,
# 88  July  28,  2003             27  July 28,
# 89  July  29,  2003             11  July 29,
# 90  July  30,  2003             18  July 30,
#
# [91 rows x 5 columns]

# %% [markdown]
# *Note: I can't figure out how to get the year, also, but since they're all the same year I'm using like this*
#
# **Create line graph with matplotlib**

# %%
plt.plot(heartAttacks['Date'], heartAttacks['Heart Attacks'])
plt.xlabel('Date')
plt.ylabel('Heart Attacks')
plt.title('Heart Attacks by Month in 2003')
# Out:
# Text(0.5, 1.0, 'Heart Attacks by Month in 2003')

# %% [markdown]
# *Note: There seems to be no correlation between date and number of heart attacks, though there are slightly more overall at the end of the summer / data - interesting that the line ends up looking like a heartbeat though ;)*
