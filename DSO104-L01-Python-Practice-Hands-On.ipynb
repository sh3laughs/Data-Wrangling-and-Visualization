# %% [markdown]
# ## DSO104 - Data Wrangling and Visualization
# ### Lesson 1 - Manipulating Columns and Rows
# ______________
# #### Page 13 - [Practice] Hands-On
#
# **Import packages**

# %%
import pandas as pd

# %% [markdown]
# **Import data**

# %%
fakeNews = pd.read_excel('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 1: Data Wrangling and Visualization/FakeNews.xlsx')

# %%
fakeNews
# Out:
#                      when                                                url  \
# 0         before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 1         before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 2         before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 3         before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 4         before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# ...                   ...                                                ...
# 3334  2017-03-01 00:00:00  https://www.ncscooper.com/transgender-dog-unsu...
# 3335  2017-03-01 00:00:00  https://www.ncscooper.com/transgender-dog-unsu...
# 3336  2017-03-01 00:00:00  https://www.ncscooper.com/transgender-dog-unsu...
# 3337  2017-03-01 00:00:00  https://www.ncscooper.com/transgender-dog-unsu...
# 3338  2017-03-01 00:00:00  https://www.ncscooper.com/transgender-dog-unsu...
#
#                              tracker
# ...

# %% [markdown]
# **1- Add a column labeled `StoryType` and fill it with `Fake`.**

# %%
fakeNews['StoryType'] = 'Fake'

fakeNews.head()
# Out:
#               when                                                url  \
# 0  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 1  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 2  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 3  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 4  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake

# %% [markdown]
# **2- Remove the `when` column.**

# %%
fakeNews.drop(['when'], axis=1, inplace=True)

fakeNews.head()
# Out:
#                                                  url  \
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake

# %% [markdown]
# *Note: I couldn't figure out how to save the updated version of the dataset, with column removed, to a new variable – what I tried just returned errors that imply it's being saved as an alternate data type... see below, I reran code above through line 105 repeatedly before running each of these to reproduce accurate error (and not one aboout 'when' already being missing)*

# %%
fakeNews2 = fakeNews.drop(['when'], axis=1, inplace=True)

fakeNews2.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/zg/fxyw2v_910lgtrr94rf2vw0c0000gs/T/ipykernel_672/434295901.py in <module>
#       1 fakeNews2 = fakeNews.drop(['when'], axis=1, inplace=True)
#       2
# ----> 3 fakeNews2.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
fakeNews2 = (fakeNews.drop(['when'], axis=1, inplace=True))

fakeNews2.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/zg/fxyw2v_910lgtrr94rf2vw0c0000gs/T/ipykernel_672/3471002133.py in <module>
#       1 fakeNews2 = (fakeNews.drop(['when'], axis=1, inplace=True))
#       2
# ----> 3 fakeNews2.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
fakeNews2 = [fakeNews.drop(['when'], axis=1, inplace=True)]

fakeNews2.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/zg/fxyw2v_910lgtrr94rf2vw0c0000gs/T/ipykernel_672/4123133428.py in <module>
#       1 fakeNews2 = [fakeNews.drop(['when'], axis=1, inplace=True)]
# ----> 2 fakeNews2.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %% [markdown]
# **3- Separate the `url` column out so that you can see in one column the website and in the second column the domain. For example, if you have the following in `url`, it should be broken out like this:**
#
# http://wayback.archive.org/web/20161004072420id_/http://alertchild.com/
#
# Website: http://wayback.archive.org/web/20161004072420id Domain: /http://alertchild.com/

# %%
fakeNews3 = fakeNews['url'].str.split('_', expand = True).rename(
    columns = {0: 'Website', 1: 'Domain'})

fakeNews4 = pd.concat([fakeNews, fakeNews3], axis = 1)

fakeNews4.head()
# Out:
#                                                  url  \
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
#
#                                            Website                   Domain
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# ...

# %% [markdown]
# *Notes:*
#
# * *Good news - I was able to rename the columns the way I wanted to!*
# * *Unlike in R, in Python the split column isn't removed, so this new dataset has the old version AND the split versions... no wonder the R package is TIDYr ;)*

# %%
fakeNews4.drop(['url'], axis=1, inplace=True)

fakeNews4.head()
# Out:
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
#
#                                            Website                   Domain
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 3  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 4  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/

# %% [markdown]
# **4- Put back together the domain column.**

# %%
fakeNews4['url'] = fakeNews4['Website'] + '_' + fakeNews4['Domain'].map(str)

fakeNews4.drop(['Website', 'Domain'], axis=1, inplace=True)

fakeNews4.head()
# Out:
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
#
#                                                  url
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...

# %% [markdown]
# *Note: I tried creating a new variable with the new, re-merged column, but it didn't work - see attempt and error below*

# %%
fakeNews5['url'] = fakeNews4['Website'] + '_' + fakeNews4['Domain'].map(str)

fakeNews5.drop(['Website', 'Domain'], axis=1, inplace=True)

fakeNews5.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/zg/fxyw2v_910lgtrr94rf2vw0c0000gs/T/ipykernel_672/4043263198.py in <module>
# ----> 1 fakeNews5['url'] = fakeNews4['Website'] + '_' + fakeNews4['Domain'].map(str)
#       2
#       3 fakeNews5.drop(['Website', 'Domain'], axis=1, inplace=True)
#       4
#       5 fakeNews5.head()
#
# NameError: name 'fakeNews5' is not defined

# %% [markdown]
# **5- Keep only the first ten rows of the data.**

# %%
fakeNews6 = fakeNews4[:10]

fakeNews6
# Out:
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
# 5                           Kixer      Fake
# 6                  Google Adsense      Fake
# 7                     DoubleClick      Fake
# 8                     DoubleClick      Fake
# 9              Google Syndication      Fake
#
#                                                  url
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
# 5  http://wayback.archive.org/web/20161004072420i...
# 6  http://wayback.archive.org/web/20161004072420i...
# ...
