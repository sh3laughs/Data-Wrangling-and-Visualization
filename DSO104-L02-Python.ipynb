# %% [markdown]
# ## DSO104 - Data Wrangling and Visualization
# ### Lesson 2 - Data Transformations
# ______________
# #### Page 1 - Data Science
#
# *From workshop*

# %%
import pandas as pd

# %% [markdown]
# **Load data**

# %%
payments = pd.read_csv('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 2: Data Transformations/payment.csv')

# %%
payments
# Out:
#     userID          Upayment
# 0    U1001              cash
# 1    U1002              cash
# 2    U1003              cash
# 3    U1004              cash
# 4    U1004  bank_debit_cards
# ..     ...               ...
# 172  U1134              cash
# 173  U1135              cash
# 174  U1136              cash
# 175  U1137              cash
# 176  U1138              cash
#
# [177 rows x 2 columns]

# %%
profiles = pd.read_csv('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 2: Data Transformations/profile.csv')

# %%
profiles
# Out:
#     userID   latitude   longitude smoker     drink_level dress_preference  \
# 0    U1001  22.139997 -100.978803  false      abstemious         informal
# 1    U1002  22.150087 -100.983325  false      abstemious         informal
# 2    U1003  22.119847 -100.946527  false  social drinker           formal
# 3    U1004  18.867000  -99.183000  false      abstemious         informal
# 4    U1005  22.183477 -100.959891  false      abstemious    no preference
# ..     ...        ...         ...    ...             ...              ...
# 133  U1134  22.149654 -100.998610  false  casual drinker    no preference
# 134  U1135  22.170396 -100.949936  false  casual drinker         informal
# 135  U1136  22.149607 -100.997235   true  social drinker    no preference
# 136  U1137  22.144803 -100.944623  false  social drinker           formal
# 137  U1138  22.152884 -100.939663  false  social drinker           formal
#
#     ambience  transport marital_status        hijos  birth_year      interest  \
# ...

# %%
test = pd.read_csv('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 2: Data Transformations/test.csv')

# %%
test
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.938404         -0.920091         -0.667683         -0.952501
# ...

# %%
train = pd.read_csv('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 2: Data Transformations/train.csv')

# %%
train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %% [markdown]
# **Transpose data**

# %%
payments.T
# Out:
#             0      1      2      3                 4      5      6      7    \
# userID    U1001  U1002  U1003  U1004             U1004  U1005  U1006  U1007
# Upayment   cash   cash   cash   cash  bank_debit_cards   cash   cash   cash
#
#             8      9    ...    167    168    169               170    171  \
# userID    U1008  U1009  ...  U1129  U1131  U1132             U1133  U1133
# Upayment   cash   cash  ...   cash   cash   cash  bank_debit_cards   cash
#
#             172    173    174    175    176
# userID    U1134  U1135  U1136  U1137  U1138
# Upayment   cash   cash   cash   cash   cash
#
# [2 rows x 177 columns]

# %%
payments1 = payments.set_index('userID').T

payments1.head()
# Out:
# userID   U1001 U1002 U1003 U1004             U1004 U1005 U1006 U1007 U1008  \
# Upayment  cash  cash  cash  cash  bank_debit_cards  cash  cash  cash  cash
#
# userID   U1009  ... U1129 U1131 U1132             U1133 U1133 U1134 U1135  \
# Upayment  cash  ...  cash  cash  cash  bank_debit_cards  cash  cash  cash
#
# userID   U1136 U1137 U1138
# Upayment  cash  cash  cash
#
# [1 rows x 177 columns]

# %%
payments.head()
# Out:
#   userID          Upayment
# 0  U1001              cash
# 1  U1002              cash
# 2  U1003              cash
# 3  U1004              cash
# 4  U1004  bank_debit_cards

# %% [markdown]
# **Merging datasets**

# %%
userData = pd.merge(payments, profiles, on = 'userID')

userData.head()
# Out:
#   userID          Upayment   latitude   longitude smoker     drink_level  \
# 0  U1001              cash  22.139997 -100.978803  false      abstemious
# 1  U1002              cash  22.150087 -100.983325  false      abstemious
# 2  U1003              cash  22.119847 -100.946527  false  social drinker
# 3  U1004              cash  18.867000  -99.183000  false      abstemious
# 4  U1004  bank_debit_cards  18.867000  -99.183000  false      abstemious
#
#   dress_preference ambience transport marital_status        hijos  birth_year  \
# 0         informal   family   on foot         single  independent        1989
# 1         informal   family    public         single  independent        1990
# 2           formal   family    public         single  independent        1989
# 3         informal   family    public         single  independent        1940
# 4         informal   family    public         single  independent        1940
#
# ...

# %%
userData2 = pd.merge(profiles, payments, on = 'userID')

userData2.head()
# Out:
#   userID   latitude   longitude smoker     drink_level dress_preference  \
# 0  U1001  22.139997 -100.978803  false      abstemious         informal
# 1  U1002  22.150087 -100.983325  false      abstemious         informal
# 2  U1003  22.119847 -100.946527  false  social drinker           formal
# 3  U1004  18.867000  -99.183000  false      abstemious         informal
# 4  U1004  18.867000  -99.183000  false      abstemious         informal
#
#   ambience transport marital_status        hijos  birth_year    interest  \
# 0   family   on foot         single  independent        1989     variety
# 1   family    public         single  independent        1990  technology
# 2   family    public         single  independent        1989        none
# 3   family    public         single  independent        1940     variety
# 4   family    public         single  independent        1940     variety
#
#            personality  religion      activity  color  weight  budget  height  \
# ...

# %% [markdown]
# **Concatenate - append**

# %%
bodyData = pd.concat([test, train])

bodyData.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %% [markdown]
# *Check info for combined dataframe and confirm by checking info for existing dataframes - and calculate rows for all*

# %%
bodyData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10299 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 44.3+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2947 entries, 0 to 2946
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 12.7+ MB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
10299 - 2947 - 7352
# Out:
# 0

# %% [markdown]
# *Info aligns - roughly confirms it was a success*

# %% [markdown]
# **Group by - aggregate**

# %%
userData.groupby('dress_preference')['birth_year'].mean()
# Out:
# dress_preference
# ?                1985.500000
# elegant          1987.875000
# formal           1988.387755
# informal         1979.574468
# no preference    1985.239437
# Name: birth_year, dtype: float64

# %% [markdown]
# *Viewing avg. birth year by dress type preference*
#
# *Testing with less arguments*

# %%
userData.groupby('dress_preference')['birth_year']

# %% [markdown]
# *Doesn't work to leave statistical parameter off*

# %%
userData.groupby('dress_preference')

# %% [markdown]
# *Doesn't work to leave categorical parameter off*

# %% [markdown]
# ______________
# #### Page 5 - Transposing Data in Python
#
# **Load data**

# %%
tea = pd.read_csv('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 2: Data Transformations/tea.csv')

# %%
tea
# Out:
#     Year  Consumption  RealPrice  RealNationalIncome
# 0   1924        395.5       24.2                3391
# 1   1925        398.7       24.4                3640
# 2   1926        403.1       25.0                3567
# 3   1927        410.0       25.2                3827
# 4   1928        417.4       25.7                3843
# 5   1929        430.0       23.0                3928
# 6   1930        440.0       22.0                4017
# 7   1931        456.0       22.3                3877
# 8   1932        455.0       21.4                3922
# 9   1933        435.3       22.6                4162
# 10  1934        430.5       24.2                4419
# 11  1935        441.5       24.2                4656
# 12  1936        438.5       24.8                4850

# %% [markdown]
# **Transpose**

# %%
tea.T
# Out:
#                         0       1       2       3       4       5       6   \
# Year                1924.0  1925.0  1926.0  1927.0  1928.0  1929.0  1930.0
# Consumption          395.5   398.7   403.1   410.0   417.4   430.0   440.0
# RealPrice             24.2    24.4    25.0    25.2    25.7    23.0    22.0
# RealNationalIncome  3391.0  3640.0  3567.0  3827.0  3843.0  3928.0  4017.0
#
#                         7       8       9       10      11      12
# Year                1931.0  1932.0  1933.0  1934.0  1935.0  1936.0
# Consumption          456.0   455.0   435.3   430.5   441.5   438.5
# RealPrice             22.3    21.4    22.6    24.2    24.2    24.8
# RealNationalIncome  3877.0  3922.0  4162.0  4419.0  4656.0  4850.0

# %% [markdown]
# **Update top column to be the horizontal index instead**

# %%
tea2 = tea.set_index('Year').T

tea2
# Out:
# Year                  1924    1925    1926    1927    1928    1929    1930  \
# Consumption          395.5   398.7   403.1   410.0   417.4   430.0   440.0
# RealPrice             24.2    24.4    25.0    25.2    25.7    23.0    22.0
# RealNationalIncome  3391.0  3640.0  3567.0  3827.0  3843.0  3928.0  4017.0
#
# Year                  1931    1932    1933    1934    1935    1936
# Consumption          456.0   455.0   435.3   430.5   441.5   438.5
# RealPrice             22.3    21.4    22.6    24.2    24.2    24.8
# RealNationalIncome  3877.0  3922.0  4162.0  4419.0  4656.0  4850.0

# %% [markdown]
# **Re-transpose**

# %%
tea3 = tea2.T

tea3
# Out:
#       Consumption  RealPrice  RealNationalIncome
# Year
# 1924        395.5       24.2              3391.0
# 1925        398.7       24.4              3640.0
# 1926        403.1       25.0              3567.0
# 1927        410.0       25.2              3827.0
# 1928        417.4       25.7              3843.0
# 1929        430.0       23.0              3928.0
# 1930        440.0       22.0              4017.0
# 1931        456.0       22.3              3877.0
# 1932        455.0       21.4              3922.0
# 1933        435.3       22.6              4162.0
# 1934        430.5       24.2              4419.0
# 1935        441.5       24.2              4656.0
# 1936        438.5       24.8              4850.0

# %% [markdown]
# **Testing options for `set_index()` function**

# %%
tea4 = tea.set_index(['Year'])

tea4
# Out:
#       Consumption  RealPrice  RealNationalIncome
# Year
# 1924        395.5       24.2                3391
# 1925        398.7       24.4                3640
# 1926        403.1       25.0                3567
# 1927        410.0       25.2                3827
# 1928        417.4       25.7                3843
# 1929        430.0       23.0                3928
# 1930        440.0       22.0                4017
# 1931        456.0       22.3                3877
# 1932        455.0       21.4                3922
# 1933        435.3       22.6                4162
# 1934        430.5       24.2                4419
# 1935        441.5       24.2                4656
# 1936        438.5       24.8                4850

# %% [markdown]
# *As expected, without including the `.T` function, it made the row a vertical index*

# %%
tea

tea
# Out:
#     Year  Consumption  RealPrice  RealNationalIncome
# 0   1924        395.5       24.2                3391
# 1   1925        398.7       24.4                3640
# 2   1926        403.1       25.0                3567
# 3   1927        410.0       25.2                3827
# 4   1928        417.4       25.7                3843
# 5   1929        430.0       23.0                3928
# 6   1930        440.0       22.0                4017
# 7   1931        456.0       22.3                3877
# 8   1932        455.0       21.4                3922
# 9   1933        435.3       22.6                4162
# 10  1934        430.5       24.2                4419
# 11  1935        441.5       24.2                4656
# 12  1936        438.5       24.8                4850

# %% [markdown]
# *Without including an `inplace` argument, the `set_index` update was temporary and didn't actually update the dataframe*

# %% [markdown]
# ______________
# #### Page 14 - Merging Datasets in Python
#
# **Import data**

# %%
judgesAspectsUnique = pd.read_excel('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 2: Data Transformations/judgesAspectsUnique.xlsx')

# %%
judgesAspectsUnique
# Out:
#       aspect_id performance_id     section  aspect_num  \
# 0    05e699518c       34240511  components         NaN
# 1    2d91942db0      332369044  components         NaN
# 2    0146bc8a4c     7518697566    elements         1.0
# 3    07b750074e     8872285901  components         NaN
# 4    15c7461b61     9690094547  components         NaN
# ..          ...            ...         ...         ...
# 245  04bc3ec529     f9b3b1bf16    elements         8.0
# 246  00e9dadd37     fc5091d2ac    elements         7.0
# 247  257aec5a78     fc7bf0fcb0    elements         1.0
# 248  00cdab892f     fe9c5c9bc0    elements         2.0
# 249  312f82ecb0     ff8d775f98  components         NaN
#
#                      aspect_desc info_flag credit_flag  base_value  factor  \
# 0                    Composition       NaN         NaN         NaN     0.8
# 1                    Composition       NaN         NaN         NaN     0.8
# 2                        3Lz+3T<         <         NaN         9.0     NaN
# ...

# %%
performances = pd.read_excel('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 2: Data Transformations/performances.xlsx')

# %%
performances
# Out:
#     performance_id                competition  \
# 0         34240511  Olympic Winter Games 2018
# 1        332369044  Olympic Winter Games 2018
# 2       7518697566  Olympic Winter Games 2018
# 3       8872285901  Olympic Winter Games 2018
# 4       9690094547  Olympic Winter Games 2018
# ..             ...                        ...
# 245     f9b3b1bf16  Olympic Winter Games 2018
# 246     fc5091d2ac  Olympic Winter Games 2018
# 247     fc7bf0fcb0  Olympic Winter Games 2018
# 248     fe9c5c9bc0  Olympic Winter Games 2018
# 249     ff8d775f98  Olympic Winter Games 2018
#
#                                            program  \
# 0          Team Event - Pair Skating Short Program
# 1                          Ice Dance - Short Dance
# 2            Ladies Single Skating - Short Program
# 3                     Pair Skating - Short Program
# 4               Team Event - Ice Dance Short Dance
# ..                                             ...
# ...

# %% [markdown]
# **`pd.merge` to Merge**

# %%
iceSkating = pd.merge(judgesAspectsUnique, performances)

iceSkating
# Out:
#       aspect_id performance_id     section  aspect_num  \
# 0    05e699518c       34240511  components         NaN
# 1    2d91942db0      332369044  components         NaN
# 2    0146bc8a4c     7518697566    elements         1.0
# 3    07b750074e     8872285901  components         NaN
# 4    15c7461b61     9690094547  components         NaN
# ..          ...            ...         ...         ...
# 245  04bc3ec529     f9b3b1bf16    elements         8.0
# 246  00e9dadd37     fc5091d2ac    elements         7.0
# 247  257aec5a78     fc7bf0fcb0    elements         1.0
# 248  00cdab892f     fe9c5c9bc0    elements         2.0
# 249  312f82ecb0     ff8d775f98  components         NaN
#
#                      aspect_desc info_flag credit_flag  base_value  factor  \
# 0                    Composition       NaN         NaN         NaN     0.8
# 1                    Composition       NaN         NaN         NaN     0.8
# 2                        3Lz+3T<         <         NaN         9.0     NaN
# ...

# %%
iceSkating2 = pd.merge(judgesAspectsUnique, performances, on = 'performance_id')

iceSkating2
# Out:
#                                              aspect_id performance_id  \
# 0                                           05e699518c       34240511
# 1                                           2d91942db0      332369044
# 2                                           0146bc8a4c     7518697566
# 3                                           07b750074e     8872285901
# 4                                           15c7461b61     9690094547
# 5                                           11c801464a     00c3e17bd3
# 6                                           049332df3e     011d526566
# 7                                           0e8b38ab1b     01a3f2a443
# 8                                           126d118e5d     01ef6a14a8
# 9                                           0bc5a06c6b     02c6b6bb2f
# 10                                          15cfea00b8     0343e98a78
# 11                                          00d583edf0     0496311fa6
# ...

# %% [markdown]
# ______________
# #### Page 15 - Appending Datasets in Python
#
# **Import data**

# %%
muscles1 = pd.read_excel('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 2: Data Transformations/muscles1.xlsx')

# %%
muscles1
# Out:
#     BodyMass  WorkLevel  HeatOutput  Country
# 0       43.7       19.0         177  Britain
# 1       43.7       43.0         279  Britain
# 2       43.7       56.0         346  Britain
# 3       54.6       13.0         160  Britain
# 4       54.6       19.0         193  Britain
# 5       54.6       43.0         280  Britain
# 6       54.6       56.0         335  Britain
# 7       55.7       13.0         169  Britain
# 8       55.7       26.0         212  Britain
# 9       55.7       34.5         244  Britain
# 10      55.7       43.0         285  Britain
# 11      58.8       13.0         181  Britain
# 12      58.8       43.0         298  Britain
# 13      60.5       19.0         212  Britain
# 14      60.5       43.0         317  Britain
# 15      60.5       56.0         347  Britain
# 16      61.9       13.0         186  Britain
# 17      61.9       19.0         216  Britain
# 18      61.9       34.5         265  Britain
# 19      61.9       43.0         306  Britain
# ...

# %%
muscles2 = pd.read_excel('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 2: Data Transformations/muscles2.xlsx')

# %%
muscles2
# Out:
#     BodyMass  WorkLevel  HeatOutput  Country
# 0       76.2      156.8        3398  Algeria
# 1       71.3      114.1        2988  Algeria
# 2       69.6      142.6        3048  Algeria
# 3       58.0      142.6        2781  Algeria
# 4       74.6      142.6        2912  Algeria
# 5       68.9      128.3        3135  Algeria
# 6       69.1      142.6        3261  Algeria
# 7       62.1      156.8        3030  Algeria
# 8       68.7      128.3        3139  Algeria
# 9       65.4      142.6        2996  Algeria
# 10      70.4      128.3        3248  Algeria
# 11      69.1      142.6        3117  Algeria
# 12      63.7      142.6        2891  Algeria
# 13      62.1      114.1        2667  Algeria
# 14      73.5      142.6        3403  Algeria
# 15      61.3      129.4        2999  Algeria
# 16      70.1      137.5        3318  Algeria
# 17      79.8      121.3        2989  Algeria
# 18      61.3      129.4        2936  Algeria
# 19      64.8      137.5        3020  Algeria
# ...

# %% [markdown]
# **`pd.concat` function**

# %%
muscles3 = pd.concat([muscles1, muscles2])

muscles3
# Out:
#     BodyMass  WorkLevel  HeatOutput  Country
# 0       43.7       19.0         177  Britain
# 1       43.7       43.0         279  Britain
# 2       43.7       56.0         346  Britain
# 3       54.6       13.0         160  Britain
# 4       54.6       19.0         193  Britain
# ..       ...        ...         ...      ...
# 32      66.2      121.3        2733  Algeria
# 33      74.5      121.3        2808  Algeria
# 34      67.7       97.1        2813  Algeria
# 35      57.5       97.1        2615  Algeria
# 36      70.4      113.2        2814  Algeria
#
# [61 rows x 4 columns]

# %% [markdown]
# **`verify_integrity` argument**

# %%
muscles4 = pd.concat([muscles1, muscles2], verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zg/fxyw2v_910lgtrr94rf2vw0c0000gs/T/ipykernel_25428/4088518671.py in <module>
# ----> 1 muscles4 = pd.concat([muscles1, muscles2], verify_integrity=True)
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#
# ...

# %%
pd.options.display.max_rows = None
muscles3
# Out:
#     BodyMass  WorkLevel  HeatOutput  Country
# 0       43.7       19.0         177  Britain
# 1       43.7       43.0         279  Britain
# 2       43.7       56.0         346  Britain
# 3       54.6       13.0         160  Britain
# 4       54.6       19.0         193  Britain
# 5       54.6       43.0         280  Britain
# 6       54.6       56.0         335  Britain
# 7       55.7       13.0         169  Britain
# 8       55.7       26.0         212  Britain
# 9       55.7       34.5         244  Britain
# 10      55.7       43.0         285  Britain
# 11      58.8       13.0         181  Britain
# 12      58.8       43.0         298  Britain
# 13      60.5       19.0         212  Britain
# 14      60.5       43.0         317  Britain
# 15      60.5       56.0         347  Britain
# 16      61.9       13.0         186  Britain
# 17      61.9       19.0         216  Britain
# 18      61.9       34.5         265  Britain
# 19      61.9       43.0         306  Britain
# ...

# %% [markdown]
# **`ignore_index` argument**

# %%
muscles4 = pd.concat([muscles1, muscles2], ignore_index=True)

muscles4
# Out:
#     BodyMass  WorkLevel  HeatOutput  Country
# 0       43.7       19.0         177  Britain
# 1       43.7       43.0         279  Britain
# 2       43.7       56.0         346  Britain
# 3       54.6       13.0         160  Britain
# 4       54.6       19.0         193  Britain
# 5       54.6       43.0         280  Britain
# 6       54.6       56.0         335  Britain
# 7       55.7       13.0         169  Britain
# 8       55.7       26.0         212  Britain
# 9       55.7       34.5         244  Britain
# 10      55.7       43.0         285  Britain
# 11      58.8       13.0         181  Britain
# 12      58.8       43.0         298  Britain
# 13      60.5       19.0         212  Britain
# 14      60.5       43.0         317  Britain
# 15      60.5       56.0         347  Britain
# 16      61.9       13.0         186  Britain
# 17      61.9       19.0         216  Britain
# 18      61.9       34.5         265  Britain
# 19      61.9       43.0         306  Britain
# ...

# %%
pd.options.display.max_rows = 20

pd.options.display.max_rows
# Out:
# 20

# %% [markdown]
# ______________
# #### Page 16 - Data Aggregation in Python
#
# **`groupby` function**

# %%
states = pd.read_csv('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 2: Data Transformations/states.csv')

# %%
states
# Out:
#        State  Cases
# 0   Michigan      5
# 1   Michigan      7
# 2   Michigan      6
# 3   Michigan      4
# 4   Michigan      6
# ..       ...    ...
# 34   Georgia      8
# 35   Georgia      3
# 36   Georgia      6
# 37   Georgia      4
# 38   Georgia      8
#
# [39 rows x 2 columns]

# %%
states.groupby('State')['Cases'].sum()
# Out:
# State
# Georgia          49
# Michigan         43
# Tennessee        38
# Vermont          24
# West Virginia    88
# Name: Cases, dtype: int64

# %%
states
# Out:
#        State  Cases
# 0   Michigan      5
# 1   Michigan      7
# 2   Michigan      6
# 3   Michigan      4
# 4   Michigan      6
# ..       ...    ...
# 34   Georgia      8
# 35   Georgia      3
# 36   Georgia      6
# 37   Georgia      4
# 38   Georgia      8
#
# [39 rows x 2 columns]

# %% [markdown]
# *Confirmed that the variable was not updated, the `groupby` results were just printed*

# %%
states.groupby('State')['Cases'].max()
# Out:
# State
# Georgia          11
# Michigan          9
# Tennessee        10
# Vermont           7
# West Virginia    15
# Name: Cases, dtype: int64

# %%
states.groupby('State')['Cases'].mean()
# Out:
# State
# Georgia          6.125000
# Michigan         5.375000
# Tennessee        6.333333
# Vermont          4.800000
# West Virginia    7.333333
# Name: Cases, dtype: float64

# %%
states.groupby('State')['Cases'].median()
# Out:
# State
# Georgia          6.0
# Michigan         5.5
# Tennessee        5.5
# Vermont          6.0
# West Virginia    6.5
# Name: Cases, dtype: float64

# %%
states.groupby('State')['Cases'].min()
# Out:
# State
# Georgia          3
# Michigan         2
# Tennessee        3
# Vermont          2
# West Virginia    3
# Name: Cases, dtype: int64

# %%
states.groupby('State')['Cases'].std()
# Out:
# State
# Georgia          2.799872
# Michigan         2.133910
# Tennessee        2.658320
# Vermont          2.588436
# West Virginia    3.420083
# Name: Cases, dtype: float64
