# %% [markdown]
# ## DSO104 - Data Wrangling and Visualization
# ### Lesson 2 - Data Transformations
# ______________
# #### Page 16 - Practice Hands-On
#
# **Requirements**
#
# For this data exercise, you will be putting your data combination knowledge into practice! Below you’ll find links to two different data sets about spy planes. One has the plane specifications (“PlaneFeatures”), and the other has some registration information about the potential spy plane candidates (“PlaneCandidates”). It’s your job to combine them together, so that we can see all the data together in the same frame.
#
# [PlaneFeatures](https://repo.exeterlms.com/documents/V2/DataScience/Data-Wrang-Visual/PlaneFeatures.zip)
#
# [PlaneCandidates](https://repo.exeterlms.com/documents/V2/DataScience/Data-Wrang-Visual/PlaneCandidates.zip)
#
# **1- Should you use the merge or append function?**
#
# * Merge
# * Append

# %% [markdown]
# *Import package and load data*

# %%
import pandas as pd

# %%
planeFeatures = pd.read_excel('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 2: Data Transformations/PlaneFeatures.xlsx')

# %%
planeFeatures
# Out:
#        adshex  duration1  duration2  duration3  duration4  duration5  \
# 0           A   0.120253   0.075949   0.183544   0.335443   0.284810
# 1      A00000   0.211735   0.155612   0.181122   0.198980   0.252551
# 2      A00002   0.517241   0.103448   0.103448   0.103448   0.172414
# 3      A00008   0.125000   0.041667   0.208333   0.166667   0.458333
# 4      A0001E   0.100000   0.200000   0.200000   0.400000   0.100000
# ...       ...        ...        ...        ...        ...        ...
# 19794  ADFFFA   0.090909   0.454545   0.000000   0.454545   0.000000
# 19795  ADFFFC   0.352941   0.323529   0.176471   0.117647   0.029412
# 19796  ADFFFF   0.192308   0.423077   0.230769   0.115385   0.038462
# 19797  AE1899   0.000000   0.200000   0.000000   0.800000   0.000000
# 19798  AF6797   0.000000   0.142857   0.285714   0.142857   0.428571
#
#          boxes1    boxes2    boxes3    boxes4  ...    steer3    steer4  \
# ...

# %%
planeCandidates = pd.read_excel('/Users/hannah/Library/CloudStorage/GoogleDrive-gracesnouveaux@gmail.com/My Drive/Bethel Tech/Data Science/DSO104 Data Wrangling and Visualization/Lesson 2: Data Transformations/PlaneCandidates.xlsx')

# %%
planeCandidates
# Out:
#      other  surveil  adshex  squawk_1                                    name  \
# 0   0.0750   0.9250  A4FB3C      5310                    CITY OF MESA ARIZONA
# 1   0.0995   0.9005  A13098      4415                                     NaN
# 2   0.1010   0.8990  A7D925       230  ORANGE COUNTY SHERIFFS DEPARTMENT RNSP
# 3   0.1085   0.8915  A63E52      5306                     CHAPARRAL AIR GROUP
# 4   0.1230   0.8770  A1B621      5240                   MIDWEST AIRMOTIVE INC
# ..     ...      ...     ...       ...                                     ...
# 95  0.5485   0.4515  A4F17E      1200                       HARDING ROY A DBA
# 96  0.5505   0.4495  A287FC         0                    SUNDANCE AIRPORT LLC
# 97  0.5540   0.4460  A56412      2451                AVIATION SPECIALTIES INC
# 98  0.5575   0.4425  A94471      4401                  MIDWEST AERIAL IMAGING
# 99  0.5615   0.4385  ABA8EC         0                      MAXIM AVIATION LLC
#
#        reg
# 0    N42WB
# ...

# %% [markdown]
# *Because the data frames both have an `adshex` column, I'll merge**

# %% [markdown]
# **2- Perform your chosen function on the dataset**

# %%
planes = pd.merge(planeFeatures, planeCandidates)

planes
# Out:
#     adshex  duration1  duration2  duration3  duration4  duration5    boxes1  \
# 0   A00324   0.000000   0.000000   0.000000   0.235294   0.764706  0.000000
# 1   A005D8   0.241379   0.137931   0.137931   0.103448   0.379310  0.241379
# 2   A008A4   0.279570   0.112903   0.134409   0.118280   0.354839  0.263441
# 3   A00948   0.090909   0.545455   0.272727   0.090909   0.000000  0.272727
# 4   A00A41   0.000000   0.536585   0.195122   0.073171   0.195122  0.695122
# ..     ...        ...        ...        ...        ...        ...       ...
# 95  AD68DF   0.250000   0.225000   0.150000   0.050000   0.325000  0.325000
# 96  AD6AE4   0.430303   0.393939   0.060606   0.072727   0.042424  0.781818
# 97  ADE07E   0.500000   0.000000   0.000000   0.250000   0.250000  0.500000
# 98  ADF7A5   0.152778   0.055556   0.125000   0.263889   0.402778  0.500000
# 99  ADFCC8   0.205882   0.176471   0.352941   0.264706   0.000000  0.058824
#
# ...

# %% [markdown]
# *Note: The merge only pulled in the 100 rows with matching `adshex` index*
